# %%
# %matplotlib inline
import seaborn as sns
sns.set()

df = sns.load_dataset('iris')
sns.regplot(x = df['sepal_length'], y = df['petal_length'])

# %%
sns.violinplot(x = df['species'], y = df['sepal_length'])

# %%
cc = sns.load_dataset('car_crashes')

# %%
list(cc.columns.values)
# Out:
# ['total',
#  'speeding',
#  'alcohol',
#  'not_distracted',
#  'no_previous',
#  'ins_premium',
#  'ins_losses',
#  'abbrev']

# %%
sns.jointplot(x=cc['speeding'],y=cc['alcohol'])
# Out:
# C:\Users\joebr\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
